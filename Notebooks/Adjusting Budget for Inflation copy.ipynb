# %% [markdown]
# # Adjusting Budget for Inflation #

# %%
import numpy as np
import pandas as pd
import json

import statsmodels.api as sm

import matplotlib.pyplot as plt 
# %matplotlib inline

import random as rand
import seaborn as sns

from sklearn.metrics import mean_squared_error
#from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

from datetime import datetime

# %%
movies = pd.read_csv("movies_inflation_adjusted.csv")
movies.columns
# Out:
# Index(['id', 'adult', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count', 'cast', 'crew', 'keywords', 'Year',
#        'Ticket Price', 'ROI', 'Tickets Sold', 'Revenue in 2023', 'Month'],
#       dtype='object')

# %%
#Importing CPI Data by Year

# %%
cpi_year = pd.read_csv("CPI_data.csv")
cpi_year
# Out:
#      Year      CPI
# 0    1913    9.900
# 1    1914   10.000
# 2    1915   10.100
# 3    1916   10.900
# 4    1917   12.800
# ..    ...      ...
# 106  2019  255.657
# 107  2020  258.811
# 108  2021  270.970
# 109  2022  292.655
# 110  2023  301.836
#
# [111 rows x 2 columns]

# %%
 = movies.merge(cpi_year, how = "inner", on="Year")

# %%
budget_merged["Budget in 2023"] = (301.836/budget_merged["CPI"])*budget_merged["budget"]
budget_merged
# Out:
#          id  adult                              belongs_to_collection  \
# 0     10003  False  {'id': 86224, 'name': 'The Saint Collection', ...
# 1     10155  False                                                NaN
# 2     10336  False                                                NaN
# 3     10351  False  {'id': 135489, 'name': 'Wishmaster Collection'...
# 4     10371  False                                                NaN
# ...     ...    ...                                                ...
# 4508  60216  False                                                NaN
# 4509    618  False                                                NaN
# 4510  70368  False                                                NaN
# 4511  65203  False                                                NaN
# 4512  73969  False                                                NaN
#
#         budget                                             genres homepage  \
# ...

# %%
budget_merged.iloc[0]
# Out:
# id                                                                   10003
# adult                                                                False
# belongs_to_collection    {'id': 86224, 'name': 'The Saint Collection', ...
# budget                                                            68000000
# genres                   [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# homepage                                                               NaN
# imdb_id                                                          tt0120053
# original_language                                                       en
# original_title                                                   The Saint
# overview                 Ivan Tretiak, Russian Mafia boss who wants to ...
# popularity                                                        10.97633
# poster_path                               /uA24D8JCg21RDINMZ3vFaQYdIzW.jpg
# ...

# %%
budget_merged.to_csv('movies_budget_adjusted.csv',index=False)

# %%
movies_budget = pd.read_csv("movies_budget_adjusted.csv")
movies_budget.columns
# Out:
# Index(['id', 'adult', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count', 'cast', 'crew', 'keywords', 'Year',
#        'Ticket Price', 'ROI', 'Tickets Sold', 'Revenue in 2023', 'Month',
#        'CPI', 'Budget in 2023'],
#       dtype='object')
